# %%
import my_math

print(my_math.add(1,2))
# print(add(1,2))
# Out:
# 3

# %%
from my_math import add

print(add(2,4))
# Out:
# 6

# %%
from my_math import add as ad

print(ad(2,4))
# Out:
# 6

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# d:\data_work\python_basic\DAY10
# ['ex9_12.ipynb', 'ex9_4.ipynb', 'my_math.py', 'nb10_1.ipynb', '__pycache__']

# %%
import os

print(os.listdir(".."))
# Out:
# ['.git', '.venv', 'DAY10', 'DAY9', 'ex3', 'ex5', 'ex6', 'ex7', 'ex8', 'exe2_3.py', 'greet']

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
# greet 패키지
# greet / ko.py - ko_greet(), en.py - en_greet()

from greet import ko
from greet import en

print(ko.ko_greet("홍길동"))
print(en.en_greet("홍길동"))
# Out:
# 안녕하세요, 홍길동!
# Hello, 홍길동!
