# %%
def add(a, b):
    return a + b

add2 = add

print(f"add: {add}")
print(f"add2: {add2}")

print(add(1,3))
r1 = add(10,20)
print(f"r1 * 100 = {r1 * 100}")

r2 = add2("abc", "xyz")
print(f"abc + xyz = {r2}")

def test():
    return

r3 = test()
print(f"r3 = {r3}")
# Out:
# add: <function add at 0x00000214CEA64860>
# add2: <function add at 0x00000214CEA64860>
# 4
# r1 * 100 = 3000
# abc + xyz = abcxyz
# r3 = None

# %%
def test(a):
    x=100+a
    print(x)

print(a)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 def test(a):
#       2     x=100+a
#       3     print(x)
#       4
# ----> 5 print(a)
#       6 print(x)
#
# NameError: name 'a' is not defined
